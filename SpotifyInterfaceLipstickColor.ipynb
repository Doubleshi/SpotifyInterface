# %%
import spotipy
import json
import webbrowser

# %%
import urllib.request
import spotipy.util as util

# %%
# copy and paste the url into your browser to see what data you are getting back
request = urllib.request.Request("https://makeup-api.herokuapp.com/api/v1/products.json?brand=maybelline")
response = urllib.request.urlopen(request)

# %%
makeup = json.loads(response.read())

# %%
print(makeup)
# Out:
# [{'id': 495, 'brand': 'maybelline', 'name': 'Maybelline Face Studio Master Hi-Light Light Booster Bronzer', 'price': '14.99', 'price_sign': None, 'currency': None, 'image_link': 'https://d3t32hsnjxo7q6.cloudfront.net/i/991799d3e70b8856686979f8ff6dcfe0_ra,w158,h184_pa,w158,h184.png', 'product_link': 'https://well.ca/products/maybelline-face-studio-master_88837.html', 'website_link': 'https://well.ca', 'description': 'Maybelline Face Studio Master Hi-Light Light Boosting bronzer formula has an expert \nbalance of shade + shimmer illuminator for natural glow. Skin goes \nsoft-lit with zero glitz.\n\n\t\tFor Best Results: Brush over all shades in palette and gently sweep over \ncheekbones, brow bones, and temples, or anywhere light naturally touches\n the face.\n\n\t\t\n\t\n\n                    ', 'rating': 5.0, 'category': None, 'product_type': 'bronzer', 'tag_list': [], 'created_at': '2016-10-01T18:36:15.012Z', 'updated_at': '2017-12-23T21:08:50.624Z', 'product_api_url': 'https://make
# ...

# %%
type(makeup)
# Out:
# list

# %%
# Find dictionary matching value in list
lipstick = None
for sub in makeup:
    if sub['product_type'] == "lipstick":
        lipstick = sub
        break
# print result
print(lipstick)
# Out:
# {'id': 97, 'brand': 'maybelline', 'name': 'Maybelline Color Sensational Vivid Matte Liquid Lip Colour', 'price': '12.99', 'price_sign': None, 'currency': None, 'image_link': 'https://d3t32hsnjxo7q6.cloudfront.net/i/d0b6855d9b603a00f776de498c971b88_ra,w158,h184_pa,w158,h184.png', 'product_link': 'https://well.ca/products/maybelline-color-sensational-vivid_114538.html', 'website_link': 'https://well.ca', 'description': 'Bold, vivid color glides easily onto lips for a velvety matte finish with Maybelline Color Sensational Vivid Matte Liquid Lip Colour. \nFormula is comfortable and creamy with a smooth feel upon application. \nWith full color coverage, the result is a rich, intense lip look in a \nrange of colors from Nude Flush to Electric Pink to Vivid Violet.Features: Lip color glides on smooth to a matte finishInfused with pure pigments for high-impact colorCreamy liquid base for a soft, cushiony feel', 'rating': None, 'category': 'lipstick', 'product_type': 'lipstick', 'tag_list': [
# ...

# %%
type(lipstick)
# Out:
# dict

# %%
color_name = lipstick['product_colors']

# %%
color_name
# Out:
# [{'hex_value': '#AC7773', 'colour_name': 'Nude Thrill '},
#  {'hex_value': '#BD7A80', 'colour_name': 'Nude Flush '},
#  {'hex_value': '#D65F84', 'colour_name': 'Pink Charge '},
#  {'hex_value': '#D73D8C', 'colour_name': 'Electric Pink '},
#  {'hex_value': '#B12156', 'colour_name': 'Fuchsia Ecstasy '},
#  {'hex_value': '#BC2830', 'colour_name': 'Orange Shot '},
#  {'hex_value': '#B7233B', 'colour_name': 'Rebel Red '},
#  {'hex_value': '#8C1F48', 'colour_name': 'Berry Boost '},
#  {'hex_value': '#542A71', 'colour_name': 'Vivid Violet '},
#  {'hex_value': '#300B28', 'colour_name': 'Possessed Plum '}]

# %%
color = color_name[5]['colour_name']

# %%
color
# Out:
# 'Orange Shot '

# %%
# open file with keys and set the path to your credentials JSON file
credentials = "spotify_keys.json"
with open(credentials, "r") as keys:
    api_tokens = json.load(keys)

# %%
# read the keys and assign each to a variable
# A redirect URI, or reply URL, is the location where the authorization server sends the user once the app has been 
# successfully authorized and granted an authorization code or access token.
client_id = api_tokens["client_id"]
client_secret = api_tokens["client_secret"]
redirectURI = api_tokens["redirect"]
username = api_tokens["username"]

# %%
scope = 'user-read-private user-read-playback-state user-modify-playback-state playlist-modify-public'
token = util.prompt_for_user_token(username, scope, client_id=client_id,
                           client_secret=client_secret,
                           redirect_uri=redirectURI)

# %%
sp = spotipy.Spotify(auth=token)

# %%
track_results = sp.search(q=color, type='track', limit=50)

# %%
track_results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Orange+Shot+&type=track&offset=0&limit=50',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5kJsAiwFWEaNRPwvtkjnXz'},
#        'href': 'https://api.spotify.com/v1/artists/5kJsAiwFWEaNRPwvtkjnXz',
#        'id': '5kJsAiwFWEaNRPwvtkjnXz',
#        'name': "L'Orange",
#        'type': 'artist',
#        'uri': 'spotify:artist:5kJsAiwFWEaNRPwvtkjnXz'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/20IovKhpCSEdFWkcahqM09'},
#        'href': 'https://api.spotify.com/v1/artists/20IovKhpCSEdFWkcahqM09',
#        'id': '20IovKhpCSEdFWkcahqM09',
#        'name': 'Namir Blade',
#        'type': 'artist',
#        'uri': 'spotify:artist:20IovKhpCSEdFWkcahqM09'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
# ...

# %%
tracks = track_results['tracks']['items']

# %%
track_selection_list = []

for song in tracks:
    track_selection_list.append(song['uri'])

# %%
track_selection_list
# Out:
# ['spotify:track:70QmJtoGNbV7KcRT6oN9tp',
#  'spotify:track:6b5fPdo7XNZrwcTASG1hK7',
#  'spotify:track:6Ngps97GnSV17gGxsYX1NZ',
#  'spotify:track:5FkoSXiJPKTNyYgALRJFhD',
#  'spotify:track:1P16Nk9IlOYrxqJHGWbBZL',
#  'spotify:track:7ztEOk2rf8jzn3w5WJda9e',
#  'spotify:track:0M9eulco9wcfCXDpZa1OFt',
#  'spotify:track:3PrpfZRnllDh7cksV1ohPi',
#  'spotify:track:6Pj3meDGkdOCufJoDO9sDJ',
#  'spotify:track:5VG9iMlh5EgmtOo2FLxnGl',
#  'spotify:track:7DioVTP8vPOX9vz969bXy2',
#  'spotify:track:2VujIXR9H3DfqIa6Dk1KDE',
#  'spotify:track:3rqAT306qw5k7sYDwMutdi',
#  'spotify:track:0A06H9o8YQ47GGDlYc7TG6',
#  'spotify:track:4OIIyCAwt1AVRey6NnushP',
#  'spotify:track:4tnGj7NuMko1gsQhmTYbe1',
#  'spotify:track:6cowIQ7lhlxCtnC6v3GRUR',
#  'spotify:track:73ikISeel0UUw9I0x6y75x',
#  'spotify:track:70cLqOXtgRTedLX3kTSGAj',
#  'spotify:track:3dT6dLkrSZRzBxnVzjCBoC',
#  'spotify:track:2avRiZ390Wo7S8gIQqMpTk',
#  'spotify:track:36ptC75Bp6pKICI1lE8QHS',
#  'spotify:track:5MOcrbMgFoqFxAvBFzbahZ',
# ...

# %%
my_playlist = sp.user_playlist_create(user=username, name=color, public=True,
                                      description="Songs for Electronic Pink")
print(my_playlist)
# Out:
# {'collaborative': False, 'description': 'Songs for Electronic Pink', 'external_urls': {'spotify': 'https://open.spotify.com/playlist/7rBKA5yWHieuU76q1CuGfZ'}, 'followers': {'href': None, 'total': 0}, 'href': 'https://api.spotify.com/v1/playlists/7rBKA5yWHieuU76q1CuGfZ', 'id': '7rBKA5yWHieuU76q1CuGfZ', 'images': [], 'name': 'Orange Shot ', 'owner': {'display_name': 'Shi Shi', 'external_urls': {'spotify': 'https://open.spotify.com/user/31dvnoar6q3kxkspp7ankjp6z7pq'}, 'href': 'https://api.spotify.com/v1/users/31dvnoar6q3kxkspp7ankjp6z7pq', 'id': '31dvnoar6q3kxkspp7ankjp6z7pq', 'type': 'user', 'uri': 'spotify:user:31dvnoar6q3kxkspp7ankjp6z7pq'}, 'primary_color': None, 'public': True, 'snapshot_id': 'MSxkMTY3MDU4YWVhNWJiZWI2ZDY1ZTI1YTJiMDRjYWE1NTlmZTNjYWZh', 'tracks': {'href': 'https://api.spotify.com/v1/playlists/7rBKA5yWHieuU76q1CuGfZ/tracks', 'items': [], 'limit': 100, 'next': None, 'offset': 0, 'previous': None, 'total': 0}, 'type': 'playlist', 'uri': 'spotify:playlist:7rBKA5yWHieuU76
# ...

# %%
results = sp.user_playlist_add_tracks(username, my_playlist['id'], track_selection_list)
print(results)
# Out:
# {'snapshot_id': 'MyxiNmMzNmUxMjNmMWU3Nzg1NGU5NjcwYmJkMmU0OTc2NjlhYjIzMzdh'}

# %%
webbrowser.open(my_playlist['external_urls']['spotify'])
# Out:
# True
