# %%
import spotipy
import json
import webbrowser
import urllib.request
import spotipy.util as util

# %%
# copy and paste the url into your browser to see what data you are getting back
request = urllib.request.Request("https://weatherdbi.herokuapp.com/data/weather/toyoko")
response = urllib.request.urlopen(request)

# %%
type(response)
# Out:
# http.client.HTTPResponse

# %%
# convert this HTP response into the python dictionary
weather = json.loads(response.read())

# %%
print(weather)
# Out:
# {'region': 'Tokyo, Japan', 'currentConditions': {'dayhour': 'Thursday 12:00 AM', 'temp': {'c': 12, 'f': 53}, 'precip': '40%', 'humidity': '92%', 'wind': {'km': 10, 'mile': 6}, 'iconURL': 'https://ssl.gstatic.com/onebox/weather/64/sunny.png', 'comment': 'Clear'}, 'next_days': [{'day': 'Thursday', 'comment': 'Clear with periodic clouds', 'max_temp': {'c': 21, 'f': 70}, 'min_temp': {'c': 11, 'f': 52}, 'iconURL': 'https://ssl.gstatic.com/onebox/weather/48/sunny_s_cloudy.png'}, {'day': 'Friday', 'comment': 'Clear with periodic clouds', 'max_temp': {'c': 18, 'f': 64}, 'min_temp': {'c': 11, 'f': 52}, 'iconURL': 'https://ssl.gstatic.com/onebox/weather/48/sunny_s_cloudy.png'}, {'day': 'Saturday', 'comment': 'Cloudy with brief rain', 'max_temp': {'c': 16, 'f': 61}, 'min_temp': {'c': 9, 'f': 48}, 'iconURL': 'https://ssl.gstatic.com/onebox/weather/48/cloudy_s_rain.png'}, {'day': 'Sunday', 'comment': 'Clear with periodic clouds', 'max_temp': {'c': 16, 'f': 61}, 'min_temp': {'c': 9, 'f': 48}, 'iconURL': 'https://ssl.gstatic.com/onebox/weather/48/sunny_s_cloudy.png'}, {'day': 'Monday', 'comment': 'Cloudy', 'max_temp': {'c': 14, 'f': 57}, 'min_temp': {'c': 8, 'f': 46}, 'iconURL': 'https://ssl.gstatic.com/onebox/weather/48/cloudy.png'}, {'day': 'Tuesday', 'comment': 'Cloudy', 'max_temp': {'c': 19, 'f': 66}, 'min_temp': {'c': 9, 'f': 48}, 'iconURL': 'https://ssl.gstatic.com/onebox/weather/48/cloudy.png'}, {'day': 'Wednesday', 'comment': 'Cloudy with brief rain', 'max_temp': {'c': 22, 'f': 72}, 'min_temp': {'c': 13, 'f': 55}, 'iconURL': 'https://ssl.gstatic.com/onebox/weather/48/cloudy_s_rain.png'}, {'day': 'Thursday', 'comment': 'Cloudy periodically clear', 'max_temp': {'c': 14, 'f': 57}, 'min_temp': {'c': 7, 'f': 45}, 'iconURL': 'https://ssl.gstatic.com/onebox/weather/48/cloudy_s_sunny.png'}], 'contact_author': {'email': 'communication.with.users@gmail.com', 'auth_note': 'Mail me for feature requests, improvement, bug, help, ect... Please tell me if you want me to provide any other free easy-to-use API services'}, 'data_source': 'https://www.google.com/search?lr=lang_en&q=weather+in+toyoko'}

# %%
forecast = weather['currentConditions']['comment']
forecast
# Out:
# 'Clear'

# %%
# open file with keys and set the path to your credentials JSON file
credentials = "Spotify_keys.json"
with open(credentials, "r") as keys:
    api_tokens = json.load(keys)

# %%
# read the keys and assign each to a variable
# A redirect URI, or reply URL, is the location where the authorization server sends the user once the app has been 
# successfully authorized and granted an authorization code or access token.
client_id = api_tokens["client_id"]
client_secret = api_tokens["client_secret"]
redirectURI = api_tokens["redirect"]
username = api_tokens["username"]

# %%
# scope = special powers
scope = 'user-read-private user-read-playback-state user-modify-playback-state playlist-modify-public'
token = util.prompt_for_user_token(username, scope, client_id=client_id,
                           client_secret=client_secret,
                           redirect_uri=redirectURI)
# Out:
# Enter the URL you were redirected to: https://www.google.com/?code=AQDqdN7Zwb_b0gvZoyH8CItui0EOEtvNBqDI2WxBcnthiGNCfNBfniH-5YTU2fFV1z3VpVFUdQIcF_4yAvDhBk9N7m5CVzsaG8-M1x62HbJQrNK7A2wkGDM0xnd-i4goX_yPi_UDD7GTV1VfMFrtUc3qlMP6g3KjHsqMPn4zvTgtzsOaBex27YKacul8HQ12OusI0wpTZUYHmr5-kZpniFrqInWOjWe2DHJ4MQEJWz9g2UxiXEUHDThRFCbCsZ9BPphk-duyNKMhXeO2yGq_y9rcAreB2Jir

# %%
print(token)
# Out:
# BQA5_VFY6DIw9bfrAthgqZHn9ganiwwJZq1J_D2chSzHfKe-NLHc2Z2RyRIKmtQyy3qCCPjIEIFeiwdwhE4481TcLLv1nJmwlZ0z9SuXlPNMSjIUBfA-2KdERCCIcyqH8g7VHDHYMjmOR7b6QUOyduwhU8JAZJKCb6Wqjr-niX63wjquReK4gtsXbDAtoXTHXA-UVnnixsSG7PB28ta2y3QHIp8hE1XdmQCBypzCncmRiJ5wfQNAXrKXyC0

# %%
# Create Spotify Object - this is how we interact with our API
# Create OAuth Object
# oauth_object = spotipy.SpotifyOAuth(client_id, client_secret, redirectURI)
# Create token
# token_dict = oauth_object.get_cached_token()
# token = token_dict['access_token']
# print(token_dict)
# Create Spotify Object
sp = spotipy.Spotify(auth=token)

# %%
# q isthe key words of data what we looking for, here is Clear = forecast
track_results = sp.search(q=forecast, type='track', limit=50)

# %%
track_results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Clear&type=track&offset=0&limit=50',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Mr6zawZ90BzjY14EROmSm'},
#        'href': 'https://api.spotify.com/v1/artists/5Mr6zawZ90BzjY14EROmSm',
#        'id': '5Mr6zawZ90BzjY14EROmSm',
#        'name': 'Cybotron',
#        'type': 'artist',
#        'uri': 'spotify:artist:5Mr6zawZ90BzjY14EROmSm'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2a81I8YLdT49A5LWHxetcC'},
#      'href': 'https://api.spotify.com/v1/albums/2a81I8YLdT49A5LWHxetcC',
#      'id': '2a81I8YLdT49A5LWHxetcC',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27322527ee328b1f87789d474ff',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0222527ee328b1f87789d474ff',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485122527ee328b1f87789d474ff',
#        'width': 64}],
#      'name': 'Clear',
#      'release_date': '1990-11-29',
#      'release_date_precision': 'day',
#      'total_tracks': 9,
#      'type': 'album',
#      'uri': 'spotify:album:2a81I8YLdT49A5LWHxetcC'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Mr6zawZ90BzjY14EROmSm'},
#       'href': 'https://api.spotify.com/v1/artists/5Mr6zawZ90BzjY14EROmSm',
#       'id': '5Mr6zawZ90BzjY14EROmSm',
#       'name': 'Cybotron',
#       'type': 'artist',
#       'uri': 'spotify:artist:5Mr6zawZ90BzjY14EROmSm'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 294533,
#     'explicit': False,
#     'external_ids': {'isrc': 'USFI88300051'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5NKHUvpRs7zr0yOQjx8Exr'},
#     'href': 'https://api.spotify.com/v1/tracks/5NKHUvpRs7zr0yOQjx8Exr',
#     'id': '5NKHUvpRs7zr0yOQjx8Exr',
#     'is_local': False,
#     'name': 'Clear',
#     'popularity': 42,
#     'preview_url': 'https://p.scdn.co/mp3-preview/785a3e94060ecf5bd06d1abd6fc10e595b0d7031?cid=fe2f807852da4907920477a38fe523c2',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5NKHUvpRs7zr0yOQjx8Exr'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2exudSjTjUksRJhnF5JZYn'},
#        'href': 'https://api.spotify.com/v1/artists/2exudSjTjUksRJhnF5JZYn',
#        'id': '2exudSjTjUksRJhnF5JZYn',
#        'name': 'Pusher',
#        'type': 'artist',
#        'uri': 'spotify:artist:2exudSjTjUksRJhnF5JZYn'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1JhiIIXT9DWqEU3BYFZwGA'},
#        'href': 'https://api.spotify.com/v1/artists/1JhiIIXT9DWqEU3BYFZwGA',
#        'id': '1JhiIIXT9DWqEU3BYFZwGA',
#        'name': 'MOTHICA',
#        'type': 'artist',
#        'uri': 'spotify:artist:1JhiIIXT9DWqEU3BYFZwGA'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3LpfB9oslcNreI52eSrkMo'},
#      'href': 'https://api.spotify.com/v1/albums/3LpfB9oslcNreI52eSrkMo',
#      'id': '3LpfB9oslcNreI52eSrkMo',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d987abade8b3c32e14b1b2d8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d987abade8b3c32e14b1b2d8',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d987abade8b3c32e14b1b2d8',
#        'width': 64}],
#      'name': 'Clear',
#      'release_date': '2016-06-24',
#      'release_date_precision': 'day',
#      'total_tracks': 5,
#      'type': 'album',
#      'uri': 'spotify:album:3LpfB9oslcNreI52eSrkMo'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2exudSjTjUksRJhnF5JZYn'},
#       'href': 'https://api.spotify.com/v1/artists/2exudSjTjUksRJhnF5JZYn',
#       'id': '2exudSjTjUksRJhnF5JZYn',
#       'name': 'Pusher',
#       'type': 'artist',
#       'uri': 'spotify:artist:2exudSjTjUksRJhnF5JZYn'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1JhiIIXT9DWqEU3BYFZwGA'},
#       'href': 'https://api.spotify.com/v1/artists/1JhiIIXT9DWqEU3BYFZwGA',
#       'id': '1JhiIIXT9DWqEU3BYFZwGA',
#       'name': 'MOTHICA',
#       'type': 'artist',
#       'uri': 'spotify:artist:1JhiIIXT9DWqEU3BYFZwGA'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1DLKitfb8fshL0DtCecRpY'},
#       'href': 'https://api.spotify.com/v1/artists/1DLKitfb8fshL0DtCecRpY',
#       'id': '1DLKitfb8fshL0DtCecRpY',
#       'name': 'Shawn Wasabi',
#       'type': 'artist',
#       'uri': 'spotify:artist:1DLKitfb8fshL0DtCecRpY'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 175265,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBMKA1686496'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1AP7yzd4qSdKVcupPC827R'},
#     'href': 'https://api.spotify.com/v1/tracks/1AP7yzd4qSdKVcupPC827R',
#     'id': '1AP7yzd4qSdKVcupPC827R',
#     'is_local': False,
#     'name': 'Clear - Shawn Wasabi Remix',
#     'popularity': 56,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c6c396e99523b4480d68ae83fa9661cc855a73d8?cid=fe2f807852da4907920477a38fe523c2',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:1AP7yzd4qSdKVcupPC827R'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1GHJ2yDZhTLodOfqimd6ZK'},
#        'href': 'https://api.spotify.com/v1/artists/1GHJ2yDZhTLodOfqimd6ZK',
#        'id': '1GHJ2yDZhTLodOfqimd6ZK',
#        'name': 'Hush Moss',
#        'type': 'artist',
#        'uri': 'spotify:artist:1GHJ2yDZhTLodOfqimd6ZK'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0H5PiJtK74cXzs4A1HDmeR'},
#      'href': 'https://api.spotify.com/v1/albums/0H5PiJtK74cXzs4A1HDmeR',
#      'id': '0H5PiJtK74cXzs4A1HDmeR',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273affc7f6b8efaf1eb7639dcf6',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02affc7f6b8efaf1eb7639dcf6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851affc7f6b8efaf1eb7639dcf6',
#        'width': 64}],
#      'name': 'Clear',
#      'release_date': '2017-09-15',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:0H5PiJtK74cXzs4A1HDmeR'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1GHJ2yDZhTLodOfqimd6ZK'},
#       'href': 'https://api.spotify.com/v1/artists/1GHJ2yDZhTLodOfqimd6ZK',
#       'id': '1GHJ2yDZhTLodOfqimd6ZK',
#       'name': 'Hush Moss',
#       'type': 'artist',
#       'uri': 'spotify:artist:1GHJ2yDZhTLodOfqimd6ZK'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 242134,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZ9JZ1702018'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6OyjHEusfnpjMxewx4msTA'},
#     'href': 'https://api.spotify.com/v1/tracks/6OyjHEusfnpjMxewx4msTA',
#     'id': '6OyjHEusfnpjMxewx4msTA',
#     'is_local': False,
#     'name': 'Clear',
#     'popularity': 42,
#     'preview_url': 'https://p.scdn.co/mp3-preview/b83839cc6690ede050f7a693bdedd7c6d39f455f?cid=fe2f807852da4907920477a38fe523c2',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6OyjHEusfnpjMxewx4msTA'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1MOetFIO4hBem9p9FVP9Jo'},
#        'href': 'https://api.spotify.com/v1/artists/1MOetFIO4hBem9p9FVP9Jo',
#        'id': '1MOetFIO4hBem9p9FVP9Jo',
#        'name': 'Khantrast',
#        'type': 'artist',
#        'uri': 'spotify:artist:1MOetFIO4hBem9p9FVP9Jo'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/77IKlSWL4iSfHCdLgv76xT'},
#      'href': 'https://api.spotify.com/v1/albums/77IKlSWL4iSfHCdLgv76xT',
#      'id': '77IKlSWL4iSfHCdLgv76xT',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27327ea730b1bdbab2b0dbf2ed5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0227ea730b1bdbab2b0dbf2ed5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485127ea730b1bdbab2b0dbf2ed5',
#        'width': 64}],
#      'name': 'Clear Skies',
#      'release_date': '2022-07-23',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:77IKlSWL4iSfHCdLgv76xT'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1MOetFIO4hBem9p9FVP9Jo'},
#       'href': 'https://api.spotify.com/v1/artists/1MOetFIO4hBem9p9FVP9Jo',
#       'id': '1MOetFIO4hBem9p9FVP9Jo',
#       'name': 'Khantrast',
#       'type': 'artist',
#       'uri': 'spotify:artist:1MOetFIO4hBem9p9FVP9Jo'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 181413,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZMEM2293341'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2sHcAZQ1PxE5AqCzdrvQxu'},
#     'href': 'https://api.spotify.com/v1/tracks/2sHcAZQ1PxE5AqCzdrvQxu',
#     'id': '2sHcAZQ1PxE5AqCzdrvQxu',
#     'is_local': False,
#     'name': 'Clear Skies',
#     'popularity': 51,
#     'preview_url': 'https://p.scdn.co/mp3-preview/f0adc2ec9e6486122d29245f69db0c1f48cc30fa?cid=fe2f807852da4907920477a38fe523c2',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2sHcAZQ1PxE5AqCzdrvQxu'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/556vpAit0VPDDqxdIUTNsb'},
#        'href': 'https://api.spotify.com/v1/artists/556vpAit0VPDDqxdIUTNsb',
#        'id': '556vpAit0VPDDqxdIUTNsb',
#        'name': 'Clear Soul Forces',
#        'type': 'artist',
#        'uri': 'spotify:artist:556vpAit0VPDDqxdIUTNsb'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2Ab8j47clrLWBIU910DryC'},
#      'href': 'https://api.spotify.com/v1/albums/2Ab8j47clrLWBIU910DryC',
#      'id': '2Ab8j47clrLWBIU910DryC',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273065273f61ef56b80c852951b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02065273f61ef56b80c852951b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851065273f61ef56b80c852951b',
#        'width': 64}],
#      'name': 'Detroit Revolution(S)',
#      'release_date': '2020-03-06',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:2Ab8j47clrLWBIU910DryC'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/556vpAit0VPDDqxdIUTNsb'},
#       'href': 'https://api.spotify.com/v1/artists/556vpAit0VPDDqxdIUTNsb',
#       'id': '556vpAit0VPDDqxdIUTNsb',
#       'name': 'Clear Soul Forces',
#       'type': 'artist',
#       'uri': 'spotify:artist:556vpAit0VPDDqxdIUTNsb'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 286334,
#     'explicit': True,
#     'external_ids': {'isrc': 'QZACR2000186'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3q5oDe7Li71bfOpr865pKW'},
#     'href': 'https://api.spotify.com/v1/tracks/3q5oDe7Li71bfOpr865pKW',
#     'id': '3q5oDe7Li71bfOpr865pKW',
#     'is_local': False,
#     'name': 'Get No Better',
#     'popularity': 44,
#     'preview_url': 'https://p.scdn.co/mp3-preview/52d058428d7bb64a0e8b7916aa46975176c52c1a?cid=fe2f807852da4907920477a38fe523c2',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:3q5oDe7Li71bfOpr865pKW'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Sq9h4GMnTD99EyfZmYgqe'},
#        'href': 'https://api.spotify.com/v1/artists/5Sq9h4GMnTD99EyfZmYgqe',
#        'id': '5Sq9h4GMnTD99EyfZmYgqe',
#        'name': 'Portable',
#        'type': 'artist',
#        'uri': 'spotify:artist:5Sq9h4GMnTD99EyfZmYgqe'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5gR0gzNTr3zEFYucD94n5X'},
#      'href': 'https://api.spotify.com/v1/albums/5gR0gzNTr3zEFYucD94n5X',
#      'id': '5gR0gzNTr3zEFYucD94n5X',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273de8b6b641ebde24d2039055d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02de8b6b641ebde24d2039055d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851de8b6b641ebde24d2039055d',
#        'width': 64}],
#      'name': 'Clear',
#      'release_date': '2022-04-08',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:5gR0gzNTr3zEFYucD94n5X'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Sq9h4GMnTD99EyfZmYgqe'},
#       'href': 'https://api.spotify.com/v1/artists/5Sq9h4GMnTD99EyfZmYgqe',
#       'id': '5Sq9h4GMnTD99EyfZmYgqe',
#       'name': 'Portable',
#       'type': 'artist',
#       'uri': 'spotify:artist:5Sq9h4GMnTD99EyfZmYgqe'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 205920,
#     'explicit': False,
#     'external_ids': {'isrc': 'NLRD52046075'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3Y487cCOeeWAwOt0jYyThv'},
#     'href': 'https://api.spotify.com/v1/tracks/3Y487cCOeeWAwOt0jYyThv',
#     'id': '3Y487cCOeeWAwOt0jYyThv',
#     'is_local': False,
#     'name': 'Clear',
#     'popularity': 34,
#     'preview_url': 'https://p.scdn.co/mp3-preview/732d6358771d1c5e51840b635dc7bfb3a810c041?cid=fe2f807852da4907920477a38fe523c2',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3Y487cCOeeWAwOt0jYyThv'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3IYUhFvPQItj6xySrBmZkd'},
#        'href': 'https://api.spotify.com/v1/artists/3IYUhFvPQItj6xySrBmZkd',
#        'id': '3IYUhFvPQItj6xySrBmZkd',
#        'name': 'Creedence Clearwater Revival',
#        'type': 'artist',
#        'uri': 'spotify:artist:3IYUhFvPQItj6xySrBmZkd'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/31q47gQszFt0CddSyMksgO'},
#      'href': 'https://api.spotify.com/v1/albums/31q47gQszFt0CddSyMksgO',
#      'id': '31q47gQszFt0CddSyMksgO',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739f39192f9f8ca1c90847b3e5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029f39192f9f8ca1c90847b3e5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519f39192f9f8ca1c90847b3e5',
#        'width': 64}],
#      'name': 'Willy And The Poor Boys (Expanded Edition)',
#      'release_date': '1969-11-02',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:31q47gQszFt0CddSyMksgO'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3IYUhFvPQItj6xySrBmZkd'},
#       'href': 'https://api.spotify.com/v1/artists/3IYUhFvPQItj6xySrBmZkd',
#       'id': '3IYUhFvPQItj6xySrBmZkd',
#       'name': 'Creedence Clearwater Revival',
#       'type': 'artist',
#       'uri': 'spotify:artist:3IYUhFvPQItj6xySrBmZkd'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 140773,
#     'explicit': False,
#     'external_ids': {'isrc': 'USC4R0817618'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4BP3uh0hFLFRb5cjsgLqDh'},
#     'href': 'https://api.spotify.com/v1/tracks/4BP3uh0hFLFRb5cjsgLqDh',
#     'id': '4BP3uh0hFLFRb5cjsgLqDh',
#     'is_local': False,
#     'name': 'Fortunate Son',
#     'popularity': 82,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e5f046bad2c70464086c48ed2a5dec2b1c1114e7?cid=fe2f807852da4907920477a38fe523c2',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:4BP3uh0hFLFRb5cjsgLqDh'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2exudSjTjUksRJhnF5JZYn'},
#        'href': 'https://api.spotify.com/v1/artists/2exudSjTjUksRJhnF5JZYn',
#        'id': '2exudSjTjUksRJhnF5JZYn',
#        'name': 'Pusher',
#        'type': 'artist',
#        'uri': 'spotify:artist:2exudSjTjUksRJhnF5JZYn'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1JhiIIXT9DWqEU3BYFZwGA'},
#        'href': 'https://api.spotify.com/v1/artists/1JhiIIXT9DWqEU3BYFZwGA',
#        'id': '1JhiIIXT9DWqEU3BYFZwGA',
#        'name': 'MOTHICA',
#        'type': 'artist',
#        'uri': 'spotify:artist:1JhiIIXT9DWqEU3BYFZwGA'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
# ...
#      'total_tracks': 4,
#      'type': 'album',
#      'uri': 'spotify:album:5JQPaANFirVn64GlE2ncfE'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4QevbRsYpbNF2Ln9WfjGGQ'},
#       'href': 'https://api.spotify.com/v1/artists/4QevbRsYpbNF2Ln9WfjGGQ',
#       'id': '4QevbRsYpbNF2Ln9WfjGGQ',
#       'name': 'Team Of Sounds',
#       'type': 'artist',
#       'uri': 'spotify:artist:4QevbRsYpbNF2Ln9WfjGGQ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 154167,
#     'explicit': False,
#     'external_ids': {'isrc': 'SE5IB2162695'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5G5PbKe0820KuHNLj9pXKX'},
#     'href': 'https://api.spotify.com/v1/tracks/5G5PbKe0820KuHNLj9pXKX',
#     'id': '5G5PbKe0820KuHNLj9pXKX',
#     'is_local': False,
#     'name': 'Clear Your Mind',
#     'popularity': 47,
#     'preview_url': 'https://p.scdn.co/mp3-preview/df3c27745fffb48e2221f624aee65423f6b65e85?cid=fe2f807852da4907920477a38fe523c2',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5G5PbKe0820KuHNLj9pXKX'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4W0SWJnXGnnJenDbbT2jp8'},
#        'href': 'https://api.spotify.com/v1/artists/4W0SWJnXGnnJenDbbT2jp8',
#        'id': '4W0SWJnXGnnJenDbbT2jp8',
#        'name': 'Chude Mni',
#        'type': 'artist',
#        'uri': 'spotify:artist:4W0SWJnXGnnJenDbbT2jp8'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6cvZYYUBczk9LVFW3vtOLh'},
#      'href': 'https://api.spotify.com/v1/albums/6cvZYYUBczk9LVFW3vtOLh',
#      'id': '6cvZYYUBczk9LVFW3vtOLh',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273367899a62f33dd6b5b414fa4',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02367899a62f33dd6b5b414fa4',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851367899a62f33dd6b5b414fa4',
#        'width': 64}],
#      'name': 'Clear Night',
#      'release_date': '2022-11-01',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:6cvZYYUBczk9LVFW3vtOLh'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4W0SWJnXGnnJenDbbT2jp8'},
#       'href': 'https://api.spotify.com/v1/artists/4W0SWJnXGnnJenDbbT2jp8',
#       'id': '4W0SWJnXGnnJenDbbT2jp8',
#       'name': 'Chude Mni',
#       'type': 'artist',
#       'uri': 'spotify:artist:4W0SWJnXGnnJenDbbT2jp8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 243600,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZTAW2269669'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3ktgP66gKAPM5jyY3CVpcW'},
#     'href': 'https://api.spotify.com/v1/tracks/3ktgP66gKAPM5jyY3CVpcW',
#     'id': '3ktgP66gKAPM5jyY3CVpcW',
#     'is_local': False,
#     'name': 'Clear Night',
#     'popularity': 23,
#     'preview_url': 'https://p.scdn.co/mp3-preview/96ce3563ce700ff7c87457cde0695be2774a1572?cid=fe2f807852da4907920477a38fe523c2',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3ktgP66gKAPM5jyY3CVpcW'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3IYUhFvPQItj6xySrBmZkd'},
#        'href': 'https://api.spotify.com/v1/artists/3IYUhFvPQItj6xySrBmZkd',
#        'id': '3IYUhFvPQItj6xySrBmZkd',
#        'name': 'Creedence Clearwater Revival',
#        'type': 'artist',
#        'uri': 'spotify:artist:3IYUhFvPQItj6xySrBmZkd'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5w2X5ZmdE4u0XGkOU7BiLG'},
#      'href': 'https://api.spotify.com/v1/albums/5w2X5ZmdE4u0XGkOU7BiLG',
#      'id': '5w2X5ZmdE4u0XGkOU7BiLG',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2736e186edfb8fe3710fdc1f7c2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e026e186edfb8fe3710fdc1f7c2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048516e186edfb8fe3710fdc1f7c2',
#        'width': 64}],
#      'name': "Cosmo's Factory",
#      'release_date': '1970-07-24',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:5w2X5ZmdE4u0XGkOU7BiLG'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3IYUhFvPQItj6xySrBmZkd'},
#       'href': 'https://api.spotify.com/v1/artists/3IYUhFvPQItj6xySrBmZkd',
#       'id': '3IYUhFvPQItj6xySrBmZkd',
#       'name': 'Creedence Clearwater Revival',
#       'type': 'artist',
#       'uri': 'spotify:artist:3IYUhFvPQItj6xySrBmZkd'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 159172,
#     'explicit': False,
#     'external_ids': {'isrc': 'USFI87000058'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/56dtB7EzO7EneUgYwX8krC'},
#     'href': 'https://api.spotify.com/v1/tracks/56dtB7EzO7EneUgYwX8krC',
#     'id': '56dtB7EzO7EneUgYwX8krC',
#     'is_local': False,
#     'name': 'Up Around The Bend',
#     'popularity': 69,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a157e22e03c1eb9154a7e26cb9151215d1a7cb24?cid=fe2f807852da4907920477a38fe523c2',
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:56dtB7EzO7EneUgYwX8krC'}],
#   'limit': 50,
#   'next': 'https://api.spotify.com/v1/search?query=Clear&type=track&offset=50&limit=50',
#   'offset': 0,
#   'previous': None,
#   'total': 11233}}

# %%
tracks = track_results['tracks']['items']

# %%
tracks[0]
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Mr6zawZ90BzjY14EROmSm'},
#     'href': 'https://api.spotify.com/v1/artists/5Mr6zawZ90BzjY14EROmSm',
#     'id': '5Mr6zawZ90BzjY14EROmSm',
#     'name': 'Cybotron',
#     'type': 'artist',
#     'uri': 'spotify:artist:5Mr6zawZ90BzjY14EROmSm'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/2a81I8YLdT49A5LWHxetcC'},
#   'href': 'https://api.spotify.com/v1/albums/2a81I8YLdT49A5LWHxetcC',
#   'id': '2a81I8YLdT49A5LWHxetcC',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27322527ee328b1f87789d474ff',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0222527ee328b1f87789d474ff',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485122527ee328b1f87789d474ff',
#     'width': 64}],
#   'name': 'Clear',
#   'release_date': '1990-11-29',
#   'release_date_precision': 'day',
#   'total_tracks': 9,
#   'type': 'album',
#   'uri': 'spotify:album:2a81I8YLdT49A5LWHxetcC'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Mr6zawZ90BzjY14EROmSm'},
#    'href': 'https://api.spotify.com/v1/artists/5Mr6zawZ90BzjY14EROmSm',
#    'id': '5Mr6zawZ90BzjY14EROmSm',
#    'name': 'Cybotron',
#    'type': 'artist',
#    'uri': 'spotify:artist:5Mr6zawZ90BzjY14EROmSm'}],
#  'available_markets': ['AD',
#   'AE',
#   'AG',
#   'AL',
#   'AM',
#   'AO',
#   'AR',
#   'AT',
#   'AU',
#   'AZ',
#   'BA',
#   'BB',
#   'BD',
#   'BE',
#   'BF',
#   'BG',
#   'BH',
#   'BI',
#   'BJ',
#   'BN',
#   'BO',
#   'BR',
#   'BS',
#   'BT',
#   'BW',
#   'BY',
#   'BZ',
#   'CA',
#   'CD',
#   'CG',
#   'CH',
#   'CI',
#   'CL',
#   'CM',
#   'CO',
#   'CR',
#   'CV',
#   'CW',
#   'CY',
#   'CZ',
#   'DE',
#   'DJ',
#   'DK',
#   'DM',
#   'DO',
#   'DZ',
#   'EC',
#   'EE',
#   'EG',
#   'ES',
#   'FI',
#   'FJ',
#   'FM',
#   'FR',
#   'GA',
#   'GB',
#   'GD',
#   'GE',
#   'GH',
#   'GM',
#   'GN',
#   'GQ',
#   'GR',
#   'GT',
#   'GW',
#   'GY',
#   'HK',
#   'HN',
#   'HR',
#   'HT',
#   'HU',
#   'ID',
#   'IE',
#   'IL',
#   'IN',
#   'IQ',
#   'IS',
#   'IT',
#   'JM',
#   'JO',
#   'JP',
#   'KE',
#   'KG',
#   'KH',
#   'KI',
#   'KM',
#   'KN',
#   'KR',
#   'KW',
#   'KZ',
#   'LA',
#   'LB',
#   'LC',
#   'LI',
#   'LK',
#   'LR',
#   'LS',
#   'LT',
#   'LU',
#   'LV',
#   'LY',
#   'MA',
#   'MC',
#   'MD',
#   'ME',
#   'MG',
#   'MH',
#   'MK',
#   'ML',
#   'MN',
#   'MO',
#   'MR',
#   'MT',
#   'MU',
#   'MV',
#   'MW',
#   'MX',
#   'MY',
#   'MZ',
#   'NA',
#   'NE',
#   'NG',
#   'NI',
#   'NL',
#   'NO',
#   'NP',
#   'NR',
#   'NZ',
#   'OM',
#   'PA',
#   'PE',
#   'PG',
#   'PH',
#   'PK',
#   'PL',
#   'PS',
#   'PT',
#   'PW',
#   'PY',
#   'QA',
#   'RO',
#   'RS',
#   'RW',
#   'SA',
#   'SB',
#   'SC',
#   'SE',
#   'SG',
#   'SI',
#   'SK',
#   'SL',
#   'SM',
#   'SN',
#   'SR',
#   'ST',
#   'SV',
#   'SZ',
#   'TD',
#   'TG',
#   'TH',
#   'TJ',
#   'TL',
#   'TN',
#   'TO',
#   'TR',
#   'TT',
#   'TV',
#   'TW',
#   'TZ',
#   'UA',
#   'UG',
#   'US',
#   'UY',
#   'UZ',
#   'VC',
#   'VE',
#   'VN',
#   'VU',
#   'WS',
#   'XK',
#   'ZA',
#   'ZM',
#   'ZW'],
#  'disc_number': 1,
#  'duration_ms': 294533,
#  'explicit': False,
#  'external_ids': {'isrc': 'USFI88300051'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/5NKHUvpRs7zr0yOQjx8Exr'},
#  'href': 'https://api.spotify.com/v1/tracks/5NKHUvpRs7zr0yOQjx8Exr',
#  'id': '5NKHUvpRs7zr0yOQjx8Exr',
#  'is_local': False,
#  'name': 'Clear',
#  'popularity': 42,
#  'preview_url': 'https://p.scdn.co/mp3-preview/785a3e94060ecf5bd06d1abd6fc10e595b0d7031?cid=fe2f807852da4907920477a38fe523c2',
#  'track_number': 1,
#  'type': 'track',
#  'uri': 'spotify:track:5NKHUvpRs7zr0yOQjx8Exr'}

# %%
# URI = uniform resource identifier
track_selection_list = []

for song in tracks:
    track_selection_list.append(song['uri'])

# %%
track_selection_list
# Out:
# ['spotify:track:5NKHUvpRs7zr0yOQjx8Exr',
#  'spotify:track:1AP7yzd4qSdKVcupPC827R',
#  'spotify:track:6OyjHEusfnpjMxewx4msTA',
#  'spotify:track:2sHcAZQ1PxE5AqCzdrvQxu',
#  'spotify:track:3q5oDe7Li71bfOpr865pKW',
#  'spotify:track:0f3OnMFWmEjOAA9324JL22',
#  'spotify:track:3Y487cCOeeWAwOt0jYyThv',
#  'spotify:track:4BP3uh0hFLFRb5cjsgLqDh',
#  'spotify:track:6Jfn2Ut4F7snIXmOp7LLco',
#  'spotify:track:7og0yYDILUS6cP0TGuopsl',
#  'spotify:track:2LawezPeJhN4AWuSB0GtAU',
#  'spotify:track:0ptjIq1XKNYBtfjzXQ3dXE',
#  'spotify:track:4PUHahQp7n7ePj9NQs2CQ8',
#  'spotify:track:5XBqGcLYOZi8CEW83Ug7Fs',
#  'spotify:track:6Oy3YnBQkXQwTz7vi3MIzp',
#  'spotify:track:3lZADlRNZaQ6kx1wm8CSxR',
#  'spotify:track:0hTenOns6LBffrOtLg3rMe',
#  'spotify:track:0wCWfjqo0FV1CDseDGD0cV',
#  'spotify:track:3cqfh9a5jb97gLuICOCIw1',
#  'spotify:track:1UyIDfGrJgjCVu9VIoByiG',
#  'spotify:track:20OFwXhEXf12DzwXmaV7fj',
#  'spotify:track:38Rpr805FrkCySZ62PdJFM',
#  'spotify:track:11DjZQEZ69EXLo77HVj6yW',
#  'spotify:track:4Y312PyFlaUlszXpjvK8je',
#  'spotify:track:3B1yKSNdLOzHQZjkCxFZUg',
#  'spotify:track:6X9NUQAwFa2IFyUATVsQgf',
#  'spotify:track:63OQ4HIBZQAI5v0SDgTxK9',
#  'spotify:track:7qK3sX9MNReAgUQ6jdTAWC',
#  'spotify:track:2RcbRwAFUxaiO3rszuEqsz',
#  'spotify:track:2tCmr9BYhSjQilIomSM8EI',
#  'spotify:track:7mQiGAxZAgRiNI5ywAPYWT',
#  'spotify:track:6sBMEgQccfUCo9GfmWrm9j',
#  'spotify:track:6pxWv6GV35VGmcPf5dh6CH',
#  'spotify:track:4UEs7H32py3zfPCor8nbZZ',
#  'spotify:track:3TFkBg4Ykbemy3QeIztw70',
#  'spotify:track:6YkP0P7VPAENzoRjy8ojV2',
#  'spotify:track:2pyYQUIzASS5grzIbHMP9s',
#  'spotify:track:5liQj4sVRmEEESvvcb64o8',
#  'spotify:track:6uH0ZQicZnk5l1SEYzNYuI',
#  'spotify:track:1AwowzWKGRtas4r1Q6Sa2q',
#  'spotify:track:2s94myRSz7iYruFNz75Zxf',
#  'spotify:track:2gE95JskwQ1pCACTpGe1Db',
#  'spotify:track:7tVi4yOjp7SEfwYipYFYcz',
#  'spotify:track:6LLyyfz8BYrHtd3yPkrPad',
#  'spotify:track:0DcrhZ12WcCqruCs8ibXSf',
#  'spotify:track:4HHqIoIrq4ayS1l8fRsUvt',
#  'spotify:track:5G5PbKe0820KuHNLj9pXKX',
#  'spotify:track:3ktgP66gKAPM5jyY3CVpcW',
#  'spotify:track:56dtB7EzO7EneUgYwX8krC',
#  'spotify:track:0Z0mDrOHCvbtvHwNdv2LKg']

# %%
my_playlist = sp.user_playlist_create(user=username, name=forecast, public=True,
                                      description="Songs for the weather")
print(my_playlist)
# Out:
# {'collaborative': False, 'description': 'Songs for the weather', 'external_urls': {'spotify': 'https://open.spotify.com/playlist/2O0N5cA9uO4miW4p6JTnpZ'}, 'followers': {'href': None, 'total': 0}, 'href': 'https://api.spotify.com/v1/playlists/2O0N5cA9uO4miW4p6JTnpZ', 'id': '2O0N5cA9uO4miW4p6JTnpZ', 'images': [], 'name': 'Clear', 'owner': {'display_name': 'Shi Shi', 'external_urls': {'spotify': 'https://open.spotify.com/user/31dvnoar6q3kxkspp7ankjp6z7pq'}, 'href': 'https://api.spotify.com/v1/users/31dvnoar6q3kxkspp7ankjp6z7pq', 'id': '31dvnoar6q3kxkspp7ankjp6z7pq', 'type': 'user', 'uri': 'spotify:user:31dvnoar6q3kxkspp7ankjp6z7pq'}, 'primary_color': None, 'public': True, 'snapshot_id': 'MSw5NDczZmEyM2UzNmE1ZWUzNWEwZGMzNGRiYmQ0OThlMzkzOTVmOTlk', 'tracks': {'href': 'https://api.spotify.com/v1/playlists/2O0N5cA9uO4miW4p6JTnpZ/tracks', 'items': [], 'limit': 100, 'next': None, 'offset': 0, 'previous': None, 'total': 0}, 'type': 'playlist', 'uri': 'spotify:playlist:2O0N5cA9uO4miW4p6JTnpZ'}

# %%
results = sp.user_playlist_add_tracks(username, my_playlist['id'], track_selection_list)
print(results)
# Out:
# {'snapshot_id': 'MywxZDkxMWU1MDM0NTIzMjI0NDFkMDUzZDBmNTdiOGMyNjZlZGNkNDlh'}

# %%
# sp.start_playback(deviceID, None, track_selection_list)
webbrowser.open(my_playlist['external_urls']['spotify'])
# Out:
# True
